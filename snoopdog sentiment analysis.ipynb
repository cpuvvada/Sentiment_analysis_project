# %% [markdown]
# <img src = "https://upload.wikimedia.org/wikipedia/commons/4/42/Snoop_Dogg_snapped_attending_a_press_conference_in_India.jpg", width = 300 x 100>

# %% [markdown]
# ## Goals
# ---
#
# Create a an application to rank infuencers for target marketing
# - Create a developer account on Twitter
# - Create a method to pull a list of tweets from the Twitter API
# - Perform proper preprocessing on our text
# - Engineer sentiment feature in our dataset using TextBlob
# - Explore supervised classification techniques

# %% [markdown]
# ## Twitter API Developer Registration
# ---
#
# If you haven't registered a Twitter account yet, this is a requirement in order to have a "developer" account.
#
# [Twitter Rest API](https://dev.twitter.com/rest/public)

# %% [markdown]
# ## Create an "App"
#
# ---
#
# ![](https://snag.gy/HPBQbJ.jpg)
#
# Go to Twitter and register an "app" [apps.twitter.com](https://apps.twitter.com/).
#
# > **Note**: For the required website field you can put a placeholder.
#
# After you set up our app, you will only need to reference the cooresponding keys Twitter generates for our app.  These are the keys that we will use with our application to communicate with the Twitter API.

# %% [markdown]
# ## Install Python Twitter API library
#
# ---
#
# Someone was nice enough to build a Python libary for us. It makes pulling tweets simple: we only need to plug in our keys and start collecting data. The library we will be using is provided by [Python Twitter Tools](http://mike.verdone.ca/twitter/).
#
# To install it, uncomment and run the next frame (there is no conda package).

# %%
# !pip install twitter python-twitter
# Out:
# Requirement already satisfied: twitter in /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages
# Requirement already satisfied: python-twitter in /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages
# Requirement already satisfied: requests in /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages (from python-twitter)
# Requirement already satisfied: requests-oauthlib in /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages (from python-twitter)
# Requirement already satisfied: future in /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages (from python-twitter)
# Requirement already satisfied: oauthlib>=0.6.2 in /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages (from requests-oauthlib->python-twitter)

# %% [markdown]
# ## Some Boring Twitter Rules
# ---
#
# **Twitter notifies you they will rate limit your requests:**
#
# >When using application-only authentication, rate limits are determined globally for the entire application. If a method allows for 15 requests per rate limit window, then it allows you to make 15 requests per window — on behalf of your application. This limit is considered completely separately from per-user limits. https://dev.twitter.com/rest/public/rate-limiting
#
# Here's a quick overview of what Twitter says are "the rules":
#
# ![](https://snag.gy/yJ6vIH.jpg)

# %% [markdown]
# ## About those Keys: OAuth Review
# ---
#
# ![](https://g.twimg.com/dev/documentation/image/appauth_0.png)

# %% [markdown]
# ## What's going on here?  Take a minute..

# %% [markdown]
# ## Our Application Keys
# ---
#
# Take note of your application keys you will use to connect to Twitter and mine tweets from the official Bernie Sanders and Donald Trump twitter accounts:
#
# ![](https://snag.gy/H1djQK.jpg)

# %% [markdown]
# ## `TweetMiner` class structure
#
# ---
#
# The following code will get you up and running, providing connectivity to twitter. The class has the ability to make requests and can eventually transform the JSON responses into DataFrames.
#
# This is a great example of using object-oriented Python to organize our code!
#
# > **Note:** "request_limit" is used in this class to limit the number of tweets that are pulled per instance request.  Setting it to something lower until you've worked the bugs out of your request, and captured the data you want, is essential to avoiding the rate limit blocks.
#
# ### Twitter API key setup
#
# Fill the information below in with the keys for your account.
#
# - **consumer_key** - Find this in your app page under the "Keys and Access Tokens"
# - **consumer_secret** - Right under **consumer_key** in the "Keys and Access Tokens" tab
# - **access_token_key** - You will need to click the button to generate tokens to get this
# - **access_token_secret** - Also available after you generate tokens

# %%
import twitter, re, datetime, pandas as pd
from collections import defaultdict

# your keys go here:
twitter_keys = {
    'consumer_key':        'VgoJyqsPKIJiJFKCZ0jxtK2K0',
    'consumer_secret':     '2a4LDYNR2HnkLBkCLgtpmdCTcqKSD9pRjTIU2LXRKkbQz6DXQD',
    'access_token_key':    '202347836-xYk1wedC9Ohb1hW1cnm480pe4HyjemEVxVGkYJW6',
    'access_token_secret': 'kpgjoxRgAWrMx0OUWit8Rv3cYFEoLGGDBGzRKGRWHQBMt'
}

api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret']
)

# %% [markdown]
# ## Instantiate the class
# ---
#
# Make sure you pass the keys dictionary and the api as arguments.
#
# **Check:** call the object's `mine_user_tweets()` method, providing a user to pull the tweets of.

# %%
class TweetMiner(object):

    result_limit    =   500   
    api             =   False
    data            =   []
    
    def __init__(self, keys_dict, api, result_limit = 20):
        
        self.api = api
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="SnoopDogg", mine_rewteets=False, max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            
            if last_tweet_id:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.result_limit, max_id=last_tweet_id - 1)        
            else:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.result_limit)
                
            for item in statuses:

                mined = {
                    'tweet_id':        item.id,
                    'handle':          item.user.name,
                    'retweet_count':   item.retweet_count,
                    'text':            item.text,
                    'mined_at':        datetime.datetime.now(),
                    'created_at':      item.created_at,
                }
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %% [markdown]
# ## Instantiate the class
# ---
#
# Make sure you pass the keys dictionary and the api as arguments.
#
# **Check:** call the object's `mine_user_tweets()` method, providing a user to pull the tweets of.

# %%
# Instantiate TweeterMiner

miner = TweetMiner(keys_dict = twitter_keys, api = api, result_limit=500)

# %%
snoopdogg = miner.mine_user_tweets(user = 'SnoopDogg')
aerosmith = miner.mine_user_tweets(user = 'aerosmith')
flagaline = miner.mine_user_tweets(user = 'FLAGALine')
lovato = miner.mine_user_tweets(user = 'ddlovato')

# %%
snoopdogg
# Out:
# [{'created_at': u'Sat Oct 14 18:10:48 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330596),
#   'retweet_count': 34,
#   'text': u'Oct 27 new snoop Dogg. \U0001f525\U0001f525\U0001f525\U0001f50c\U0001f1fa\U0001f1f8 https://t.co/9oH0Clgkiv https://t.co/eVUJA9q3m3',
#   'tweet_id': 919264239222771712},
#  {'created_at': u'Sat Oct 14 16:44:52 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330607),
#   'retweet_count': 102,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/zIp4SjWan7 https://t.co/Oz2FbIv0n4',
#   'tweet_id': 919242611763838978},
#  {'created_at': u'Sat Oct 14 16:44:40 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330610),
#   'retweet_count': 472,
#   'text': u'https://t.co/YV4XhnNCwI https://t.co/kRXxomBSXI',
#   'tweet_id': 919242564670296064},
#  {'created_at': u'Sat Oct 14 03:58:46 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330612),
#   'retweet_count': 16,
#   'text': u'RT @TheOffical357: @SnoopDogg finna take over television',
#   'tweet_id': 919049816579043334},
#  {'created_at': u'Sat Oct 14 03:57:11 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330615),
#   'retweet_count': 3,
#   'text': u"RT @BoltVanderNerd: @JokersWildTBS @SnoopDogg Again,I cannot stress enough about how I cannot wait to watch the #JokersWild! Snoop's gonna\u2026",
#   'tweet_id': 919049418996715520},
#  {'created_at': u'Sat Oct 14 03:56:48 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330618),
#   'retweet_count': 5,
#   'text': u"RT @BartMan247: @WinkMartindale what do you think of my man @SnoopDogg doing the reboot of #JokersWild ? Snoop looks like he's holdin it do\u2026",
#   'tweet_id': 919049323656110080},
#  {'created_at': u'Sat Oct 14 03:50:46 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330621),
#   'retweet_count': 370,
#   'text': u'@awonderland @Pouyalilpou same',
#   'tweet_id': 919047804810440705},
#  {'created_at': u'Fri Oct 13 23:36:04 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330623),
#   'retweet_count': 29,
#   'text': u"It's about that time \U0001f64c\U0001f3ff who watchin ? https://t.co/ZBVK2zY3TF https://t.co/RPaI5rVt0z",
#   'tweet_id': 918983709067329536},
#  {'created_at': u'Fri Oct 13 23:31:54 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330626),
#   'retweet_count': 44,
#   'text': u'who watchin ? #jokerswild https://t.co/S9VzYLHfjh',
#   'tweet_id': 918982658591416320},
#  {'created_at': u'Fri Oct 13 23:10:21 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330629),
#   'retweet_count': 217,
#   'text': u'RT @JokersWildTBS: Can a rap kingpin turn into a game show host overnight? See for yourself in "Gettin Wild with @SnoopDogg" today at 4:20\u2026',
#   'tweet_id': 918977237105360896},
#  {'created_at': u'Fri Oct 13 18:41:21 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330631),
#   'retweet_count': 135,
#   'text': u'tickets available 2day . @rmmpercy does it again \U0001f64c\U0001f3ff\nhttps://t.co/vkb3seJhy0 https://t.co/hh25qSJvGk',
#   'tweet_id': 918909541143650304},
#  {'created_at': u'Fri Oct 13 17:43:00 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330634),
#   'retweet_count': 1102,
#   'text': u'Sound like slavery to me \U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/Zl06jru493 https://t.co/4LPFSLx0t1',
#   'tweet_id': 918894856747053057},
#  {'created_at': u'Fri Oct 13 05:35:02 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330636),
#   'retweet_count': 273,
#   'text': u'https://t.co/gM1DPuA0Zh https://t.co/zH6ZAfbtEm',
#   'tweet_id': 918711655466393600},
#  {'created_at': u'Fri Oct 13 00:42:17 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330639),
#   'retweet_count': 95,
#   'text': u'about last night \U0001f451 #JokersWild party. #GinandJuice @Tanquerayusa https://t.co/HLacVqQwvw',
#   'tweet_id': 918637984223604736},
#  {'created_at': u'Thu Oct 12 23:56:03 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330641),
#   'retweet_count': 44,
#   'text': u'\U0001f923\U0001f923 what y\u2019all rockin wit ? https://t.co/OM3j9kFgSR',
#   'tweet_id': 918626347676659712},
#  {'created_at': u'Thu Oct 12 09:08:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330643),
#   'retweet_count': 101,
#   'text': u'My baby \U0001f496\U0001f339\U0001f618. @princessbroadus https://t.co/b35bUNiEYz https://t.co/Gf3UIOVbI5',
#   'tweet_id': 918403097441067008},
#  {'created_at': u'Thu Oct 12 08:24:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330646),
#   'retweet_count': 106,
#   'text': u'https://t.co/9PoSec3iWp https://t.co/GGGMX7mGP9',
#   'tweet_id': 918392024973414400},
#  {'created_at': u'Thu Oct 12 08:24:47 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330649),
#   'retweet_count': 87,
#   'text': u'https://t.co/tlADFXUGH1 https://t.co/ou4RrHXbZP',
#   'tweet_id': 918391989732855808},
#  {'created_at': u'Thu Oct 12 08:24:22 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330651),
#   'retweet_count': 37,
#   'text': u'@iamcardib \U0001f923\U0001f923\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f50c https://t.co/6QDrRFepB5 https://t.co/6HJQIP7BFW',
#   'tweet_id': 918391882673262592},
#  {'created_at': u'Thu Oct 12 08:23:11 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330654),
#   'retweet_count': 46,
#   'text': u'Damn.  Wce\U0001f339\U0001f496\U0001f618\U0001f618\U0001f618. @bosslady_ent https://t.co/q30MExOiRO https://t.co/IM3tigQ5SG',
#   'tweet_id': 918391587180285952},
#  {'created_at': u'Thu Oct 12 08:17:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330657),
#   'retweet_count': 136,
#   'text': u'https://t.co/17qxeDNFUo https://t.co/N6PsBAXdwo',
#   'tweet_id': 918390261390168064},
#  {'created_at': u'Thu Oct 12 00:43:58 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330659),
#   'retweet_count': 1614,
#   'text': u'https://t.co/oQgOrLIFza https://t.co/NwU682j4Xg',
#   'tweet_id': 918276021668982784},
#  {'created_at': u'Thu Oct 12 00:16:24 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330661),
#   'retweet_count': 261,
#   'text': u'what yall thinkin? \U0001f914 https://t.co/2Lq7jap3Fo',
#   'tweet_id': 918269084235476992},
#  {'created_at': u'Wed Oct 11 19:05:18 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330664),
#   'retweet_count': 842,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f1fa\U0001f1f8 https://t.co/kCrHFeeriz https://t.co/J5p8bwdamA',
#   'tweet_id': 918190790354010112},
#  {'created_at': u'Wed Oct 11 08:28:01 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330666),
#   'retweet_count': 2485,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f1fa\U0001f1f8\U0001f923\U0001f923\U0001f923\U0001f44a\U0001f3fe\U0001f50c https://t.co/ESYE6xsrF7 https://t.co/SP8d54Lv32',
#   'tweet_id': 918030415155351552},
#  {'created_at': u'Wed Oct 11 05:03:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330668),
#   'retweet_count': 288,
#   'text': u'\U0001f44a\U0001f3fe https://t.co/7F0iXQOMCm https://t.co/5SWPO9xOYr',
#   'tweet_id': 917978869357010946},
#  {'created_at': u'Wed Oct 11 01:54:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330671),
#   'retweet_count': 42,
#   'text': u'https://t.co/06LbBxC6qF https://t.co/gtN04lRFgF',
#   'tweet_id': 917931307677749248},
#  {'created_at': u'Wed Oct 11 00:40:36 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330673),
#   'retweet_count': 104,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/Ia6n7veAPe https://t.co/9QROn5m13t',
#   'tweet_id': 917912782657544195},
#  {'created_at': u'Wed Oct 11 00:07:14 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330676),
#   'retweet_count': 57,
#   'text': u"what's yo strain name? #JokersWild https://t.co/EW20FD9XqF",
#   'tweet_id': 917904387866898434},
#  {'created_at': u'Tue Oct 10 23:30:41 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330678),
#   'retweet_count': 27,
#   'text': u'its about that time \U0001f918\U0001f3ff https://t.co/Kzc36NXvkQ',
#   'tweet_id': 917895189615714306},
#  {'created_at': u'Tue Oct 10 23:09:41 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330681),
#   'retweet_count': 152,
#   'text': u'https://t.co/LsGhp0n2fv https://t.co/vlDsY9QQMI',
#   'tweet_id': 917889903362543617},
#  {'created_at': u'Tue Oct 10 23:07:23 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330683),
#   'retweet_count': 754,
#   'text': u'\U0001f1fa\U0001f1f8\U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/QnwLvlSxHW https://t.co/Rp9t2CDZK8',
#   'tweet_id': 917889327111311360},
#  {'created_at': u'Tue Oct 10 22:15:14 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330686),
#   'retweet_count': 214,
#   'text': u'#Repost @smokingpounds:\n...\nPuff Puff Pass Homies \U0001f64f\U0001f3fc\U0001f4a8#SmokewithSNOOP #smokingpounds #snoopdogg #smokeweedeveryday \u2026\u2026 https://t.co/qYEiFkii2m',
#   'tweet_id': 917876200948797441},
#  {'created_at': u'Tue Oct 10 20:13:30 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330688),
#   'retweet_count': 136,
#   'text': u'I got my Bac https://t.co/cZFOeSkDaf https://t.co/hfOwVNZ2vf',
#   'tweet_id': 917845565773316096},
#  {'created_at': u'Tue Oct 10 20:11:00 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330691),
#   'retweet_count': 59,
#   'text': u'\U0001f525\U0001f525. @bosslady_ent https://t.co/2qx2vAttkd https://t.co/JLg7kiRNLg',
#   'tweet_id': 917844939026903040},
#  {'created_at': u'Tue Oct 10 20:07:10 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330693),
#   'retweet_count': 411,
#   'text': u'From now on. \U0001f44a\U0001f3fe https://t.co/tLLVVho1YK https://t.co/7ygOgRGXFO',
#   'tweet_id': 917843973082877952},
#  {'created_at': u'Tue Oct 10 18:50:30 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330696),
#   'retweet_count': 57,
#   'text': u'\U0001f64c\U0001f3ff https://t.co/ZU0ArVGCYP',
#   'tweet_id': 917824680551079936},
#  {'created_at': u'Tue Oct 10 18:21:57 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330698),
#   'retweet_count': 62,
#   'text': u'doin what i love . @tanquerayusa on deck . #ginandjuice #tanquerayten https://t.co/qGYZtkBk7C https://t.co/XIpwg5G4hf',
#   'tweet_id': 917817493963575299},
#  {'created_at': u'Tue Oct 10 15:17:11 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330701),
#   'retweet_count': 2105,
#   'text': u'https://t.co/zQAPLr2Utl https://t.co/vWFlfaWAsU',
#   'tweet_id': 917770998199607296},
#  {'created_at': u'Tue Oct 10 11:28:44 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330703),
#   'retweet_count': 429,
#   'text': u'Ubitchu https://t.co/MJO8DmpA5A https://t.co/5uURws4Skp',
#   'tweet_id': 917713506455248896},
#  {'created_at': u'Tue Oct 10 10:01:46 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330706),
#   'retweet_count': 1630,
#   'text': u'Facts.  Ubitchu https://t.co/fFidd9ANeh https://t.co/PGMAgeyaSF',
#   'tweet_id': 917691620119728128},
#  {'created_at': u'Tue Oct 10 00:00:18 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330708),
#   'retweet_count': 39,
#   'text': u'RT @BossHossMOB: @JokersWildTBS Trees &amp; Trims #IfSnoopOwnedABarberShop https://t.co/v1hrKt7kwb',
#   'tweet_id': 917540255321882624},
#  {'created_at': u'Mon Oct 09 22:30:05 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330710),
#   'retweet_count': 702,
#   'text': u'when this gets 100 retweets, i\u2019ll reveal something special on my IG story!! #jokerswild. https://t.co/nz1ceDSEFB',
#   'tweet_id': 917517550090465280},
#  {'created_at': u'Mon Oct 09 17:30:50 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330713),
#   'retweet_count': 106,
#   'text': u'treat that sweet tooth . \U0001f64c\U0001f3ff\U0001f36c #Repost @leafsbysnoop \u30fb\u30fb\u30fb\n#ChocolateBars #LeafsBySnoop #FruitChews #SnoopsFave #smoki\u2026\u2026 https://t.co/PHaCO0m1eL',
#   'tweet_id': 917442243287494657},
#  {'created_at': u'Mon Oct 09 15:57:32 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330715),
#   'retweet_count': 212,
#   'text': u'https://t.co/xjn8aeCvnj https://t.co/jji3BYFrTa',
#   'tweet_id': 917418763091415040},
#  {'created_at': u'Mon Oct 09 15:32:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330717),
#   'retweet_count': 69,
#   'text': u'\U0001f918\U0001f3ff https://t.co/tLM7n0e3F5',
#   'tweet_id': 917412573695303680},
#  {'created_at': u'Mon Oct 09 00:43:54 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330720),
#   'retweet_count': 2379,
#   'text': u'Now they do \U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f44a\U0001f3fe\U0001f1fa\U0001f1f8 https://t.co/x5KdPnCrxT https://t.co/b2tKjiol1C',
#   'tweet_id': 917188841169092609},
#  {'created_at': u'Sun Oct 08 23:38:37 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330723),
#   'retweet_count': 43,
#   'text': u'S. Y. F. L. Legend https://t.co/4U4iXHhamT https://t.co/Ucb1ilnQlq',
#   'tweet_id': 917172411296047104},
#  {'created_at': u'Sun Oct 08 23:33:25 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330726),
#   'retweet_count': 888,
#   'text': u'S. Y. F. L.  Legend. https://t.co/VvRPTOI0M6 https://t.co/mV1L5y9L7u',
#   'tweet_id': 917171103130320897},
#  {'created_at': u'Sun Oct 08 14:03:00 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330728),
#   'retweet_count': 70,
#   'text': u'https://t.co/yno6gAwr2b https://t.co/p3o0yKADow',
#   'tweet_id': 917027549863206912},
#  {'created_at': u'Sun Oct 08 06:59:07 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330730),
#   'retweet_count': 258,
#   'text': u'https://t.co/5deqF2LJmR https://t.co/X32BEj1S1o',
#   'tweet_id': 916920877354311681},
#  {'created_at': u'Sun Oct 08 02:33:47 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330733),
#   'retweet_count': 466,
#   'text': u'https://t.co/MIByEH1ezu https://t.co/LcNFKyfC8K',
#   'tweet_id': 916854103216713729},
#  {'created_at': u'Sun Oct 08 02:33:06 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330735),
#   'retweet_count': 71,
#   'text': u'Libra dove love. \U0001f44a\U0001f3fe. Happy. C. Day https://t.co/BCIBrUKYPx https://t.co/JEXlaxJzpp',
#   'tweet_id': 916853932961488897},
#  {'created_at': u'Sun Oct 08 01:45:50 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330738),
#   'retweet_count': 65,
#   'text': u'https://t.co/W94Z6V0WLT https://t.co/YB4tUTcNVq',
#   'tweet_id': 916842039182020608},
#  {'created_at': u'Sun Oct 08 01:45:13 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330740),
#   'retweet_count': 45,
#   'text': u'Happy c day. Big floss. https://t.co/Mkry1XAQvt https://t.co/TtejUF64BU',
#   'tweet_id': 916841883011338240},
#  {'created_at': u'Sat Oct 07 08:35:09 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330742),
#   'retweet_count': 87,
#   'text': u'https://t.co/RKaDrsZZMH https://t.co/UPVR25YwoJ',
#   'tweet_id': 916582656929927168},
#  {'created_at': u'Sat Oct 07 08:34:30 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330745),
#   'retweet_count': 215,
#   'text': u'\U0001f62d\U0001f62d\U0001f923\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f921\U0001f921\U0001f923\U0001f604\U0001f603\U0001f600 https://t.co/AqzSQoJloI https://t.co/Yc8teA1gCk',
#   'tweet_id': 916582494031446017},
#  {'created_at': u'Sat Oct 07 08:31:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330747),
#   'retweet_count': 138,
#   'text': u'Family 1st. \U0001f44a\U0001f3fe\U0001f50c\U0001f37e\U0001f37e\U0001f4b8\U0001f4b8 https://t.co/RBNfpCPI4s https://t.co/nW8DH2MTTI',
#   'tweet_id': 916581849400569856},
#  {'created_at': u'Sat Oct 07 05:36:51 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330752),
#   'retweet_count': 184,
#   'text': u'https://t.co/NxgDW6W7jY https://t.co/bPx0SC2lY1',
#   'tweet_id': 916537787335233536},
#  {'created_at': u'Sat Oct 07 05:36:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330757),
#   'retweet_count': 1141,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/WesUwCArpz https://t.co/0jh6xl8Xj2',
#   'tweet_id': 916537622264238080},
#  {'created_at': u'Sat Oct 07 02:37:17 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330759),
#   'retweet_count': 766,
#   'text': u'https://t.co/H2AEEMgs1x https://t.co/iyzqeYbbfP',
#   'tweet_id': 916492598910562304},
#  {'created_at': u'Sat Oct 07 02:00:36 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330762),
#   'retweet_count': 274,
#   'text': u'About last night. https://t.co/gt02aCXPOQ https://t.co/WkkplCEi4b',
#   'tweet_id': 916483367432015872},
#  {'created_at': u'Fri Oct 06 08:32:51 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330764),
#   'retweet_count': 227,
#   'text': u'Work https://t.co/zXR8RA4G26 https://t.co/LuvTqcu60Z',
#   'tweet_id': 916219691605086208},
#  {'created_at': u'Fri Oct 06 06:50:48 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330767),
#   'retweet_count': 11,
#   'text': u'@bosslady_ent \U0001f496\U0001f339 https://t.co/1qHGvaQwpc https://t.co/ZtatR3TKOW',
#   'tweet_id': 916194009315467265},
#  {'created_at': u'Fri Oct 06 06:25:39 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330769),
#   'retweet_count': 124,
#   'text': u'https://t.co/xALfIyT0r8 https://t.co/3GC0nuKlRd',
#   'tweet_id': 916187680186290176},
#  {'created_at': u'Fri Oct 06 02:08:36 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330772),
#   'retweet_count': 342,
#   'text': u'https://t.co/LfUTJ5afU5 https://t.co/oaxMDUoSO6',
#   'tweet_id': 916122992320630786},
#  {'created_at': u'Thu Oct 05 23:24:31 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330774),
#   'retweet_count': 30,
#   'text': u'who tunin in ? https://t.co/h1t1T5fCVd',
#   'tweet_id': 916081698156118017},
#  {'created_at': u'Thu Oct 05 23:16:16 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330776),
#   'retweet_count': 33,
#   'text': u'https://t.co/RLLYktxh5J https://t.co/ZpXPMIyioD',
#   'tweet_id': 916079621099151362},
#  {'created_at': u'Thu Oct 05 20:26:36 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330779),
#   'retweet_count': 220,
#   'text': u'Queens \U0001f917\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f923\U0001f923 https://t.co/tNPyeLQQS5 https://t.co/MbStBkiq10',
#   'tweet_id': 916036924673896449},
#  {'created_at': u'Thu Oct 05 19:52:39 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330782),
#   'retweet_count': 50,
#   'text': u'https://t.co/mkFDw7MGoE https://t.co/pN2j86ai6w',
#   'tweet_id': 916028378960056320},
#  {'created_at': u'Thu Oct 05 17:58:57 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330784),
#   'retweet_count': 83,
#   'text': u'R. I  P. To a real. One.  Attwill.  C p. T. \U0001f44a\U0001f3fe\U0001f64f\U0001f3fe https://t.co/GcAlkEy0k8 https://t.co/7yo60Dwv85',
#   'tweet_id': 915999764981927936},
#  {'created_at': u'Thu Oct 05 02:09:35 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330786),
#   'retweet_count': 87,
#   'text': u'Nefew showing me his grades. \U0001f44a\U0001f3fe\U0001f4b8\U0001f4b8\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f50c https://t.co/oqEza8VLmT https://t.co/HanMWxy02N',
#   'tweet_id': 915760849482129408},
#  {'created_at': u'Wed Oct 04 23:42:06 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330789),
#   'retweet_count': 107,
#   'text': u"\U0001f914 what y'all think ? https://t.co/eKvaS2xzft",
#   'tweet_id': 915723736057126914},
#  {'created_at': u'Wed Oct 04 23:20:43 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330793),
#   'retweet_count': 173,
#   'text': u'Happy c day 2 tha godfather.  @unclerush \U0001f382\U0001f382\U0001f50c\U0001f4b8 https://t.co/EbfAJEM4wS https://t.co/5cD8a7X219',
#   'tweet_id': 915718354438156288},
#  {'created_at': u'Wed Oct 04 22:31:59 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330796),
#   'retweet_count': 342,
#   'text': u'Lil cuz. @sashabankswwe https://t.co/dAIstzpnQ9 https://t.co/6mOExhNw1S',
#   'tweet_id': 915706089894809601},
#  {'created_at': u'Wed Oct 04 22:16:04 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330798),
#   'retweet_count': 6,
#   'text': u'@omargooding  I need to meet my lil Nefew he gd up from the feet up \U0001f44a\U0001f3fe\U0001f37c\U0001f37c https://t.co/xnKFXt8leg https://t.co/Eir7Z6g6dn',
#   'tweet_id': 915702085102063616},
#  {'created_at': u'Wed Oct 04 21:49:57 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330800),
#   'retweet_count': 60,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f3c0\U0001f3c0 https://t.co/hXqnpZPcdX https://t.co/U6lOccjmIo',
#   'tweet_id': 915695510081740801},
#  {'created_at': u'Wed Oct 04 20:00:06 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330803),
#   'retweet_count': 387,
#   'text': u'F. D. T. https://t.co/Ymk0oe0ip6 https://t.co/sJEENm3FjD',
#   'tweet_id': 915667868376866818},
#  {'created_at': u'Wed Oct 04 19:23:59 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330805),
#   'retweet_count': 3111,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f\U0001f3c0 https://t.co/jnyL98D1n9 https://t.co/mmQmbVB65c',
#   'tweet_id': 915658779978604544},
#  {'created_at': u'Wed Oct 04 17:43:09 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330807),
#   'retweet_count': 405,
#   'text': u'#MarthaAndSnoop comin back for season 2 . \U0001f64c\U0001f3ff https://t.co/sBUKnlsf2d',
#   'tweet_id': 915633401129873408},
#  {'created_at': u'Wed Oct 04 16:23:48 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330810),
#   'retweet_count': 201,
#   'text': u'Special time \U0001f3c8\U0001f44a\U0001f3fe\U0001f64f\U0001f3fe https://t.co/0AN3uvEj5L https://t.co/1ZC0MOyxaM',
#   'tweet_id': 915613434049433607},
#  {'created_at': u'Wed Oct 04 16:20:08 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330813),
#   'retweet_count': 108,
#   'text': u'https://t.co/XblY6vsouC https://t.co/QTDNzdtqbU',
#   'tweet_id': 915612510979575808},
#  {'created_at': u'Wed Oct 04 16:05:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330815),
#   'retweet_count': 647,
#   'text': u'https://t.co/hwlSGsPVvY https://t.co/KjaTue8Rhf',
#   'tweet_id': 915608753470361605},
#  {'created_at': u'Wed Oct 04 01:26:37 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330818),
#   'retweet_count': 96,
#   'text': u'new #ggn out now wit neff @21savage \U0001f64c\U0001f3ff https://t.co/OVccFDtlXQ',
#   'tweet_id': 915387651905150979},
#  {'created_at': u'Tue Oct 03 22:50:08 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330820),
#   'retweet_count': 109,
#   'text': u'thanks to Fatburger for hookin up the food for our Snoop Special Stars Camp this weekend \U0001f64f\U0001f3ff https://t.co/HqFQxTIkOZ',
#   'tweet_id': 915348270968225792},
#  {'created_at': u'Tue Oct 03 22:29:45 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330822),
#   'retweet_count': 55,
#   'text': u'\U0001f64f\U0001f3ff https://t.co/MiFd5GGbxa',
#   'tweet_id': 915343141250592768},
#  {'created_at': u'Tue Oct 03 21:43:35 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330825),
#   'retweet_count': 1485,
#   'text': u'https://t.co/9PmYZUIDMv https://t.co/3IQBwCgHSz',
#   'tweet_id': 915331520830824448},
#  {'created_at': u'Tue Oct 03 20:34:28 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330829),
#   'retweet_count': 113,
#   'text': u'bud inspector snoop \u270a\U0001f3ff #Repost @leafsbysnoop\n\u30fb\u30fb\u30fb\n#flashbackfriday #fbf to when @snoopdogg toured the @tweedmainstr\u2026\u2026 https://t.co/a9FKfyCTFa',
#   'tweet_id': 915314126536224768},
#  {'created_at': u'Tue Oct 03 19:19:30 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330832),
#   'retweet_count': 313,
#   'text': u'Praying for the Las Vegas victims \U0001f64f\U0001f3ff we need to step up and fight all this gun violence. I stand with Gabby and Mar\u2026 https://t.co/Usz317Vgaf',
#   'tweet_id': 915295260875485190},
#  {'created_at': u'Tue Oct 03 15:23:19 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330835),
#   'retweet_count': 231,
#   'text': u'https://t.co/4lZmfzEQyb https://t.co/k1woCJ4kC5',
#   'tweet_id': 915235822840029184},
#  {'created_at': u'Tue Oct 03 15:18:41 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330837),
#   'retweet_count': 284,
#   'text': u'https://t.co/wI0RqNqkLL https://t.co/w1yK1rFwFw',
#   'tweet_id': 915234659663011840},
#  {'created_at': u'Tue Oct 03 15:02:47 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330839),
#   'retweet_count': 499,
#   'text': u'I never do https://t.co/1tPPe6y2mt https://t.co/CkCWIwxn5l',
#   'tweet_id': 915230655138684929},
#  {'created_at': u'Tue Oct 03 14:40:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330842),
#   'retweet_count': 261,
#   'text': u'If al Davis was alive this what would b next \U0001f44a\U0001f3fe\U0001f1fa\U0001f1f8\U0001f3c8\U0001f50c https://t.co/lP3Jyxcyik https://t.co/RgWoFdGRSL',
#   'tweet_id': 915225153705054208},
#  {'created_at': u'Tue Oct 03 14:34:16 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330844),
#   'retweet_count': 519,
#   'text': u'Facts.  Treat our vets better. My pops a Vietnam vet Purple Heart. 1968. \U0001f1fa\U0001f1f8\U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/CVsX0Flqt1 https://t.co/0Ldjdlo8nf',
#   'tweet_id': 915223479741554688},
#  {'created_at': u'Tue Oct 03 14:34:13 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330847),
#   'retweet_count': 284,
#   'text': u'https://t.co/1h5gNPkZgQ https://t.co/IzFTIujj6g',
#   'tweet_id': 915223469276762113},
#  {'created_at': u'Tue Oct 03 05:04:29 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330849),
#   'retweet_count': 101,
#   'text': u"what y'all think ? https://t.co/9lDb6oqRko",
#   'tweet_id': 915080088525217794},
#  {'created_at': u'Tue Oct 03 04:36:35 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330852),
#   'retweet_count': 1489,
#   'text': u'How do u feel \U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/haieOsLLHP https://t.co/aweuqUrT2q',
#   'tweet_id': 915073068124565505},
#  {'created_at': u'Tue Oct 03 01:31:37 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330854),
#   'retweet_count': 259,
#   'text': u'https://t.co/ee4rPrBBmF https://t.co/PPWC1alFf8',
#   'tweet_id': 915026521072521216},
#  {'created_at': u'Mon Oct 02 23:16:58 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330857),
#   'retweet_count': 172,
#   'text': u'Brothers \U0001f4fd\U0001f39e\U0001f4b8\U0001f44a\U0001f3fe https://t.co/DPNkMoqLNq https://t.co/y7jeO5zovJ',
#   'tweet_id': 914992632908173312},
#  {'created_at': u'Mon Oct 02 22:52:23 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330860),
#   'retweet_count': 61,
#   'text': u'My big cuz https://t.co/v2qTbiOjeQ https://t.co/lZYoMkOuHL',
#   'tweet_id': 914986447878410240},
#  {'created_at': u'Mon Oct 02 22:52:21 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330862),
#   'retweet_count': 35,
#   'text': u'@dftwosix \U0001f3c8\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f44a\U0001f3fe. @welter47 \U0001f496\U0001f3c8\U0001f1fa\U0001f1f8 https://t.co/og63OxpGR7 https://t.co/Mwfn2JjAC2',
#   'tweet_id': 914986438139285504},
#  {'created_at': u'Mon Oct 02 22:26:22 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330867),
#   'retweet_count': 179,
#   'text': u'new \U0001f525\U0001f3b6 from neff @gherbo on the @MERRYJANE playlist .  https://t.co/QTPpgCcPgs',
#   'tweet_id': 914979901555466240},
#  {'created_at': u'Mon Oct 02 19:33:15 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330869),
#   'retweet_count': 8003,
#   'text': u'Facts. \U0001f1fa\U0001f1f8\U0001f44a\U0001f3fe\U0001f64f\U0001f3fe\U0001f496 https://t.co/fZd7Rt7kIz https://t.co/dbeqIojSu0',
#   'tweet_id': 914936333977686017},
#  {'created_at': u'Mon Oct 02 19:28:59 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330871),
#   'retweet_count': 52,
#   'text': u'https://t.co/CsGMGFjSXQ https://t.co/XPuPVLcJJN',
#   'tweet_id': 914935259703185408},
#  {'created_at': u'Mon Oct 02 19:28:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330874),
#   'retweet_count': 1081,
#   'text': u'https://t.co/hKnfvKcPlL https://t.co/WCNLZ79z8D',
#   'tweet_id': 914935248793849857},
#  {'created_at': u'Mon Oct 02 18:42:42 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330876),
#   'retweet_count': 470,
#   'text': u'Gone. But not forgotten. \U0001f339\U0001f64f\U0001f3fe. D.  12. Proof https://t.co/wO2kH4aEBZ https://t.co/46NO0zBWRV',
#   'tweet_id': 914923614440390656},
#  {'created_at': u'Mon Oct 02 17:18:05 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330879),
#   'retweet_count': 146,
#   'text': u'Good morning https://t.co/FnoiQcS4bi https://t.co/f4g7lV7GjT',
#   'tweet_id': 914902319136944135},
#  {'created_at': u'Mon Oct 02 08:58:27 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330881),
#   'retweet_count': 1088,
#   'text': u'\U0001f339\U0001f64f\U0001f3fe. Vegas https://t.co/4jbn4slh8C https://t.co/zvWAaiPSqG',
#   'tweet_id': 914776580911755264},
#  {'created_at': u'Sun Oct 01 22:16:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330884),
#   'retweet_count': 175,
#   'text': u'Bird season https://t.co/gmBXUwHKoW https://t.co/JKGXlRtlFR',
#   'tweet_id': 914614953927114752},
#  {'created_at': u'Sun Oct 01 22:13:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330886),
#   'retweet_count': 74,
#   'text': u'https://t.co/AoPX2hPaeY https://t.co/ksi6DusmBj',
#   'tweet_id': 914614380855164929},
#  {'created_at': u'Sun Oct 01 21:20:46 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330889),
#   'retweet_count': 59,
#   'text': u'https://t.co/d2Q0mhbrcP https://t.co/fVXWMy2XMy',
#   'tweet_id': 914601002413764608},
#  {'created_at': u'Sun Oct 01 21:10:39 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330891),
#   'retweet_count': 49,
#   'text': u'https://t.co/oVjSdivyFR https://t.co/HOVpDOtsFa',
#   'tweet_id': 914598458920771585},
#  {'created_at': u'Sun Oct 01 20:42:43 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330893),
#   'retweet_count': 61,
#   'text': u'https://t.co/akNYg4azQU https://t.co/Or9dCa96Ww',
#   'tweet_id': 914591427555885061},
#  {'created_at': u'Sun Oct 01 20:40:25 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330896),
#   'retweet_count': 343,
#   'text': u'Chosen few. @josh3rosen \U0001f339\U0001f3c8 https://t.co/JwreCMNihZ https://t.co/Jlhjz8tf3H',
#   'tweet_id': 914590849941610497},
#  {'created_at': u'Sun Oct 01 20:32:31 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330898),
#   'retweet_count': 68,
#   'text': u'https://t.co/EcaQQdLyTC https://t.co/YN5v6JhjRa',
#   'tweet_id': 914588862743285762},
#  {'created_at': u'Sun Oct 01 19:37:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330902),
#   'retweet_count': 57,
#   'text': u'https://t.co/BgU1AsZcMu https://t.co/fDWDnYof9x',
#   'tweet_id': 914575122719297537},
#  {'created_at': u'Sun Oct 01 16:56:25 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330905),
#   'retweet_count': 79,
#   'text': u'Snoop special needs camp today https://t.co/oqxPt9ueJi https://t.co/1g2hB2xbvo',
#   'tweet_id': 914534477656920066},
#  {'created_at': u'Sun Oct 01 16:39:09 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330907),
#   'retweet_count': 395,
#   'text': u'The juice is loose\U0001f44a\U0001f3fe\U0001f44a\U0001f3fe https://t.co/EtQQcfb0lc https://t.co/UVjwgG6Oif',
#   'tweet_id': 914530133838630913},
#  {'created_at': u'Sat Sep 30 23:58:41 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330909),
#   'retweet_count': 205,
#   'text': u'who tryin dis ? https://t.co/hGjDte1MRT',
#   'tweet_id': 914278356908048384},
#  {'created_at': u'Sat Sep 30 21:12:39 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330912),
#   'retweet_count': 620,
#   'text': u'\U0001f347\U0001f347\U0001f347\U0001f347 https://t.co/S8uZSdqIlY https://t.co/1qd0T5Ve79',
#   'tweet_id': 914236572177960961},
#  {'created_at': u'Sat Sep 30 15:25:19 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330914),
#   'retweet_count': 263,
#   'text': u'About last night https://t.co/m1ZJynnT3V https://t.co/SnHDAqEpgz',
#   'tweet_id': 914149164002496515},
#  {'created_at': u'Sat Sep 30 04:58:43 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330917),
#   'retweet_count': 260,
#   'text': u'La https://t.co/OMouy4ksOH https://t.co/ahBIiSlvVB',
#   'tweet_id': 913991474286653440},
#  {'created_at': u'Sat Sep 30 03:52:23 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330919),
#   'retweet_count': 111,
#   'text': u'Boss talk https://t.co/VeZyxQiLh5 https://t.co/amTkoEEUL6',
#   'tweet_id': 913974783104159744},
#  {'created_at': u'Sat Sep 30 03:34:38 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330921),
#   'retweet_count': 316,
#   'text': u'https://t.co/88l0IOW0cx https://t.co/ME8FOnzLw5',
#   'tweet_id': 913970315624988673},
#  {'created_at': u'Sat Sep 30 02:53:39 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330924),
#   'retweet_count': 67,
#   'text': u'Tonight @timenightclub https://t.co/QvFzOrbRjc https://t.co/9Z6ItY9bvr',
#   'tweet_id': 913960002615996416},
#  {'created_at': u'Fri Sep 29 23:30:09 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330926),
#   'retweet_count': 156,
#   'text': u'blessings on blessings . #WordsareFew ft. @BSladeNow available on all retail sites \U0001f64f\U0001f3ff\U0001f3b6 https://t.co/6Evs0XZ1tb',
#   'tweet_id': 913908787030798337},
#  {'created_at': u'Fri Sep 29 18:40:28 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330929),
#   'retweet_count': 34,
#   'text': u'https://t.co/JoDQHGdcA5 https://t.co/FHR3SgzfjE',
#   'tweet_id': 913835886692978691},
#  {'created_at': u'Fri Sep 29 17:35:44 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330931),
#   'retweet_count': 76,
#   'text': u'On iTunes right now go get it.  @hahadavis  @myguymars \U0001f525\U0001f525\U0001f50c\U0001f50c https://t.co/vHnHfhBOz6 https://t.co/GXJ6uqzbHq',
#   'tweet_id': 913819594858680320},
#  {'created_at': u'Fri Sep 29 17:27:51 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330934),
#   'retweet_count': 254,
#   'text': u"That's me \U0001f339\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe https://t.co/YzwOldcHdm https://t.co/qPkuLSAnSi",
#   'tweet_id': 913817612710236165},
#  {'created_at': u'Fri Sep 29 17:13:43 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330938),
#   'retweet_count': 155,
#   'text': u'Hot\U0001f525\U0001f525 https://t.co/gdw2sZ5621 https://t.co/doIMFEYsLJ',
#   'tweet_id': 913814058230534144},
#  {'created_at': u'Fri Sep 29 17:06:54 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330941),
#   'retweet_count': 20,
#   'text': u'RT @ImpactTVNetwork: American rap artist Snoop Dogg has released his first single titled, \u201cWords are Few,\u201d where he shares his... https://t\u2026',
#   'tweet_id': 913812342709796864},
#  {'created_at': u'Fri Sep 29 08:52:50 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330943),
#   'retweet_count': 109,
#   'text': u'My first set of great kids to win a Super Bowl for me and turn out to b greater men \U0001f3c8\U0001f44a\U0001f3fe. S. Y. F  L.  Legends\u2026 https://t.co/cEjhM9C8wn',
#   'tweet_id': 913688006405578753},
#  {'created_at': u'Fri Sep 29 05:56:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330945),
#   'retweet_count': 284,
#   'text': u'https://t.co/LxWUw0WUuo https://t.co/VVobXULn6y',
#   'tweet_id': 913643734314700800},
#  {'created_at': u'Fri Sep 29 03:46:22 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330948),
#   'retweet_count': 134,
#   'text': u'https://t.co/L81sEKlQco https://t.co/yNXUBPL87C',
#   'tweet_id': 913610878095945729},
#  {'created_at': u'Thu Sep 28 23:37:42 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330950),
#   'retweet_count': 137,
#   'text': u'cali gettin a new name . what yall think im namin it ? https://t.co/apxLQMdgYQ',
#   'tweet_id': 913548300128677888},
#  {'created_at': u'Thu Sep 28 17:45:05 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330953),
#   'retweet_count': 262,
#   'text': u'\U0001f64c\U0001f3ff #XXL20 https://t.co/lLf8mD8Wvd https://t.co/dymvMS8ajJ',
#   'tweet_id': 913459561482326016},
#  {'created_at': u'Thu Sep 28 17:41:42 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330955),
#   'retweet_count': 102,
#   'text': u'\U0001f64c\U0001f3ff #XXL20 https://t.co/pYWjFWBSVf',
#   'tweet_id': 913458712248852481},
#  {'created_at': u'Thu Sep 28 16:33:59 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330958),
#   'retweet_count': 100,
#   'text': u"RT @RedZoneChannel: ICYM @SnoopDogg in the #FantasyZone w/@MichaelRapaport talking Tom Brady's dance moves &amp; @SHAQ's rap skills! @heykayada\u2026",
#   'tweet_id': 913441669269250050},
#  {'created_at': u'Wed Sep 27 17:34:11 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330960),
#   'retweet_count': 4593,
#   'text': u'celebratin success \U0001f64c\U0001f3ff https://t.co/Y6WHTx4m4L',
#   'tweet_id': 913094429954555905},
#  {'created_at': u'Wed Sep 27 17:28:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330962),
#   'retweet_count': 47,
#   'text': u'Pomona city.  @rmmpercy https://t.co/pYGBKpWawK https://t.co/Redahi865C',
#   'tweet_id': 913093106622504961},
#  {'created_at': u'Wed Sep 27 17:24:52 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330965),
#   'retweet_count': 231,
#   'text': u'\U0001f937\U0001f3fe\u200d\u2642\ufe0f https://t.co/0BLZcKGs2h https://t.co/SeP1ABxmPM',
#   'tweet_id': 913092084504125440},
#  {'created_at': u'Tue Sep 26 18:37:30 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330967),
#   'retweet_count': 136,
#   'text': u'who smokin dis ? https://t.co/TEgo50HSp8',
#   'tweet_id': 912747977730437121},
#  {'created_at': u'Tue Sep 26 18:24:07 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330969),
#   'retweet_count': 88,
#   'text': u'https://t.co/AUGUi0rHwx https://t.co/jW3DPEM0b1',
#   'tweet_id': 912744610392309760},
#  {'created_at': u'Tue Sep 26 17:45:46 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330973),
#   'retweet_count': 325,
#   'text': u'Reprimanded for taking a knee in uniform \U0001f1fa\U0001f1f8\U0001f44a\U0001f3fe. W. T. F.  Wow. They feel the pain of the people too all police aren\u2026\u2026 https://t.co/vzGC3Bk9hd',
#   'tweet_id': 912734956786454530},
#  {'created_at': u'Tue Sep 26 17:17:17 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330976),
#   'retweet_count': 11,
#   'text': u'@fabbydavisjr1  Selling these Friday.  Get u a couple of them. Matter fact get a doZen and pass some out  F. D. T.\u2026 https://t.co/LA9qlFts1C',
#   'tweet_id': 912727791652802560},
#  {'created_at': u'Tue Sep 26 16:57:35 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330978),
#   'retweet_count': 652,
#   'text': u'Facts https://t.co/jfUJZ38dqo https://t.co/NZqFBTHwAG',
#   'tweet_id': 912722834052599808},
#  {'created_at': u'Tue Sep 26 16:55:04 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330981),
#   'retweet_count': 177,
#   'text': u'https://t.co/kFUULOocQ6 https://t.co/90atdzDk1y',
#   'tweet_id': 912722200217706496},
#  {'created_at': u'Tue Sep 26 16:46:58 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330983),
#   'retweet_count': 1569,
#   'text': u"Don't loose focus on the reason \U0001f1fa\U0001f1f8\U0001f44a\U0001f3fe\U0001f3c8 https://t.co/uYpkmZ0Iyn https://t.co/e3ivpVceTL",
#   'tweet_id': 912720161127493632},
#  {'created_at': u'Mon Sep 25 23:41:53 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330986),
#   'retweet_count': 115,
#   'text': u"picture big snoop, king of the island . what y'all callin it ? https://t.co/cTZAIHb6FD",
#   'tweet_id': 912462189931372544},
#  {'created_at': u'Mon Sep 25 22:22:19 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330989),
#   'retweet_count': 1305,
#   'text': u'https://t.co/kMo7ev7NfE https://t.co/X5ki9GOQVx',
#   'tweet_id': 912442166550630400},
#  {'created_at': u'Mon Sep 25 18:57:24 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330991),
#   'retweet_count': 1214,
#   'text': u'\U0001f1fa\U0001f1f8\U0001f44a\U0001f3fe https://t.co/UYEKC0rjL6 https://t.co/Co4xXRbji9',
#   'tweet_id': 912390598941962240},
#  {'created_at': u'Mon Sep 25 18:21:36 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330993),
#   'retweet_count': 61,
#   'text': u"who got one ? #Repost @funksac\n\u30fb\u30fb\u30fb\nAin't nothin but a green thing baby. \U0001f389 @snoopdogg. Our @Leafsbysnoop collab is \u2026\u2026 https://t.co/iVBj42hbpM",
#   'tweet_id': 912381588444459008},
#  {'created_at': u'Mon Sep 25 00:43:14 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330996),
#   'retweet_count': 2003,
#   'text': u'I love my soilders \U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f44a\U0001f3fe https://t.co/ukDcWcWkp2 https://t.co/etsdWnnnzd',
#   'tweet_id': 912115243509325824},
#  {'created_at': u'Mon Sep 25 00:29:34 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 330998),
#   'retweet_count': 394,
#   'text': u'UK dis true ? https://t.co/lvBez9vgrz',
#   'tweet_id': 912111801654845441},
#  {'created_at': u'Sun Sep 24 21:59:54 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 331000),
#   'retweet_count': 467,
#   'text': u'https://t.co/MIwakEatx8 https://t.co/d9fFgYSBXL',
#   'tweet_id': 912074137111351296},
#  {'created_at': u'Sun Sep 24 21:53:44 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 331002),
#   'retweet_count': 316,
#   'text': u'https://t.co/hhc5QIEDXX https://t.co/7exK0OLe2w',
#   'tweet_id': 912072584765820929},
#  {'created_at': u'Sun Sep 24 17:52:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 331004),
#   'retweet_count': 1262,
#   'text': u'Cuz\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f44a\U0001f3fe\U0001f1fa\U0001f1f8 https://t.co/U47swtE3hQ https://t.co/PoVwfhuoam',
#   'tweet_id': 912011983909683200},
#  {'created_at': u'Sun Sep 24 17:02:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 17, 331008),
#   'retweet_count': 399,
#   'text': u'https://t.co/pE9utPyD3U https://t.co/1ojwFICguw',
#   'tweet_id': 911999403329753088},
#  {'created_at': u'Sun Sep 24 16:48:07 +0000 2017',
# ...
#   'retweet_count': 180,
#   'text': u'Romey. Rome wit the young Dogg. \U0001f57a\U0001f3fe94. @martinlawrence https://t.co/cQpgQ6A32n https://t.co/MTcGUYQHPq',
#   'tweet_id': 880569184207466497},
#  {'created_at': u'Thu Jun 29 23:22:28 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95158),
#   'retweet_count': 96,
#   'text': u'dropped a verse on @CalvinHarris #Holiday track . new Calvin album out tomorrow \U0001f64f\U0001f3ff go n cop it ! https://t.co/wa4rVufLWl',
#   'tweet_id': 880567170798714881},
#  {'created_at': u'Thu Jun 29 19:19:53 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95161),
#   'retweet_count': 44,
#   'text': u'https://t.co/eLO8wcFImy https://t.co/ZIOTepEz5b',
#   'tweet_id': 880506122268012545},
#  {'created_at': u'Thu Jun 29 01:15:24 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95165),
#   'retweet_count': 111,
#   'text': u'89. My Playa potnas \U0001f64f\U0001f3fe\U0001f44a\U0001f3fe. Duke earl George sticky Stan and snoop \U0001f44f\U0001f3fe\U0001f44f\U0001f3fefunk house https://t.co/cqXowB6oJ8 https://t.co/OikqnZo6VZ',
#   'tweet_id': 880233203017109504},
#  {'created_at': u'Wed Jun 28 21:06:28 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95168),
#   'retweet_count': 52,
#   'text': u'neffew @ChronixxMusic takn over the @MERRYJANE playlist \U0001f525\U0001f3b6https://t.co/CyDkcMcL8v https://t.co/tpgJQTarpN',
#   'tweet_id': 880170556393312257},
#  {'created_at': u'Wed Jun 28 20:00:02 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95172),
#   'retweet_count': 37,
#   'text': u'Check out new chit from @marcosus &amp; #52Savage \u201cBoo Boo Nah Nah\u201d now on iTunes! https://t.co/u2TYlrT3dX',
#   'tweet_id': 880153837822136320},
#  {'created_at': u'Wed Jun 28 18:52:16 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95176),
#   'retweet_count': 72,
#   'text': u'new music from my neffews @WestWestZ @ItsKamalShah @FreeStreeb \u201cToo Much\u201d now on iTunes! https://t.co/zuGVHvDpkZ',
#   'tweet_id': 880136784545370112},
#  {'created_at': u'Wed Jun 28 00:32:33 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95180),
#   'retweet_count': 76,
#   'text': u'\u270a\U0001f3fe\U0001f4a8\U0001f343 https://t.co/L5YUHKqrwm',
#   'tweet_id': 879860033793646592},
#  {'created_at': u'Tue Jun 27 21:01:17 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95183),
#   'retweet_count': 80,
#   'text': u'Bet weekend at my Nefew. @tyrese  joint \U0001f525\U0001f525\U0001f525\U0001f44a\U0001f3fe https://t.co/DXlPcxaXEx https://t.co/1FZ8G44I5r',
#   'tweet_id': 879806867207319553},
#  {'created_at': u'Tue Jun 27 18:56:01 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95187),
#   'retweet_count': 100,
#   'text': u'https://t.co/6OZtyRchTP https://t.co/4GFe1MT7wk',
#   'tweet_id': 879775340540948480},
#  {'created_at': u'Tue Jun 27 18:40:49 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95191),
#   'retweet_count': 933,
#   'text': u'94. https://t.co/STk4KTvOwp https://t.co/0C1rCDAGZR',
#   'tweet_id': 879771514815430656},
#  {'created_at': u'Tue Jun 27 18:30:03 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95195),
#   'retweet_count': 120,
#   'text': u'https://t.co/WCoI13vyjM https://t.co/nMPdPJceGD',
#   'tweet_id': 879768805081321472},
#  {'created_at': u'Tue Jun 27 03:05:46 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95198),
#   'retweet_count': 32,
#   'text': u'https://t.co/dRdiPRBeFp https://t.co/FG09Ge9AHz',
#   'tweet_id': 879536204697546752},
#  {'created_at': u'Tue Jun 27 02:56:47 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95202),
#   'retweet_count': 55,
#   'text': u'https://t.co/bj6TmPOkN1 https://t.co/0uaJz86A60',
#   'tweet_id': 879533940796796928},
#  {'created_at': u'Tue Jun 27 02:45:43 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95205),
#   'retweet_count': 128,
#   'text': u'https://t.co/xsgqKylBW3 https://t.co/Vz368CxLXu',
#   'tweet_id': 879531156265422848},
#  {'created_at': u'Tue Jun 27 00:47:54 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95209),
#   'retweet_count': 82,
#   'text': u'all the treats u need . \U0001f347\U0001f352 @leafsbysnoop https://t.co/jSawCJGk8W https://t.co/j6E7VKsrX2',
#   'tweet_id': 879501507091103744},
#  {'created_at': u'Mon Jun 26 21:36:54 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95213),
#   'retweet_count': 280,
#   'text': u'https://t.co/qgYV60G6I2 https://t.co/5Nqvg9fzda',
#   'tweet_id': 879453441147514883},
#  {'created_at': u'Mon Jun 26 21:28:55 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95216),
#   'retweet_count': 809,
#   'text': u'https://t.co/cN2Mj0Mhav https://t.co/M6DSDAZlUP',
#   'tweet_id': 879451430649823233},
#  {'created_at': u'Mon Jun 26 21:27:49 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95220),
#   'retweet_count': 347,
#   'text': u'https://t.co/7plkpANxnN https://t.co/QLFvBRrx4h',
#   'tweet_id': 879451153318256640},
#  {'created_at': u'Mon Jun 26 21:26:15 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95224),
#   'retweet_count': 246,
#   'text': u'\U0001f64f\U0001f3fe https://t.co/V4abUY81dd https://t.co/qQ3BPOa4PK',
#   'tweet_id': 879450761549230080},
#  {'created_at': u'Mon Jun 26 17:43:13 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95228),
#   'retweet_count': 73,
#   'text': u'me n the neff @wattsStix on that @Tanquerayusa #TanquerayTen https://t.co/p4NnZMs8vs',
#   'tweet_id': 879394631120699392},
#  {'created_at': u'Mon Jun 26 06:24:49 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95232),
#   'retweet_count': 626,
#   'text': u'https://t.co/4ytBVz1bdr https://t.co/iAkRPFHcmd',
#   'tweet_id': 879223906024005632},
#  {'created_at': u'Mon Jun 26 04:12:44 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95236),
#   'retweet_count': 246,
#   'text': u'About last night \U0001f44a\U0001f3fe https://t.co/yLR6RjmtHO https://t.co/3CT04C85Un',
#   'tweet_id': 879190669339885568},
#  {'created_at': u'Mon Jun 26 02:26:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95240),
#   'retweet_count': 3,
#   'text': u'@hahadavis https://t.co/y10SEbKEQC https://t.co/ocLs8PWM9L',
#   'tweet_id': 879164040563625985},
#  {'created_at': u'Mon Jun 26 00:56:51 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95243),
#   'retweet_count': 35,
#   'text': u'https://t.co/Z0HZaTm4p7 https://t.co/hVo8KlFcve',
#   'tweet_id': 879141373840117760},
#  {'created_at': u'Sun Jun 25 19:57:48 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95247),
#   'retweet_count': 688,
#   'text': u"y'all know dis ? https://t.co/KvkAMBx5UE",
#   'tweet_id': 879066115401371648},
#  {'created_at': u'Sun Jun 25 15:49:57 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95251),
#   'retweet_count': 153,
#   'text': u'https://t.co/oCwTmI5trK https://t.co/tkgyLIkO7p',
#   'tweet_id': 879003738916220929},
#  {'created_at': u'Sun Jun 25 12:59:20 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95255),
#   'retweet_count': 30,
#   'text': u'https://t.co/un41K8aDb1 https://t.co/1fldaicbrq',
#   'tweet_id': 878960803063484416},
#  {'created_at': u'Sun Jun 25 12:58:04 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95259),
#   'retweet_count': 218,
#   'text': u'Thug brothers \U0001f44a\U0001f3fe\U0001f525\U0001f525 https://t.co/tWsY8UEXue https://t.co/RZDaEDX2CX',
#   'tweet_id': 878960485445644288},
#  {'created_at': u'Sun Jun 25 03:22:25 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95263),
#   'retweet_count': 40,
#   'text': u'champions hoops all summer long . @ChampsHoops https://t.co/MzrqdIXvvx',
#   'tweet_id': 878815618203504641},
#  {'created_at': u'Sat Jun 24 23:21:22 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95267),
#   'retweet_count': 251,
#   'text': u'https://t.co/3AQLitSc5D https://t.co/4N7FNtwzxC',
#   'tweet_id': 878754956337197057},
#  {'created_at': u'Sat Jun 24 23:21:20 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95271),
#   'retweet_count': 150,
#   'text': u'https://t.co/wmhK91jvEt https://t.co/xs6cY9Ai2W',
#   'tweet_id': 878754945725542400},
#  {'created_at': u'Sat Jun 24 23:17:19 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95274),
#   'retweet_count': 98,
#   'text': u'\U0001f44a\U0001f3fe\U0001f44a\U0001f3fe\U0001f44a\U0001f3fe\U0001f44f\U0001f3fe\U0001f44f\U0001f3fe\U0001f942\U0001f942\U0001f340\U0001f340 https://t.co/40q2FIV4cP https://t.co/zXKKFBN4Uq',
#   'tweet_id': 878753934545997824},
#  {'created_at': u'Sat Jun 24 20:02:29 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95278),
#   'retweet_count': 14253,
#   'text': u'mexico know wat up .\u270a\U0001f3fe\U0001f1f2\U0001f1fd https://t.co/4SWUQIyBlf',
#   'tweet_id': 878704904138706944},
#  {'created_at': u'Sat Jun 24 16:03:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95282),
#   'retweet_count': 1384,
#   'text': u'They will do a little time https://t.co/9FeMFeBIDw https://t.co/cdPq70qnBI',
#   'tweet_id': 878644688982560768},
#  {'created_at': u'Sat Jun 24 15:07:57 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95285),
#   'retweet_count': 108,
#   'text': u'Love \U0001f44a\U0001f3fe https://t.co/MOaPpt0RRA https://t.co/iqQzsTwxh3',
#   'tweet_id': 878630783178727426},
#  {'created_at': u'Sat Jun 24 15:06:12 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95289),
#   'retweet_count': 202,
#   'text': u'Cuz https://t.co/lgyt5gD6vy https://t.co/7H3Q59VzCn',
#   'tweet_id': 878630343770865665},
#  {'created_at': u'Sat Jun 24 07:14:56 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95293),
#   'retweet_count': 573,
#   'text': u'@joeybadass https://t.co/UicWnhBtst https://t.co/CZ9LoIbWVu',
#   'tweet_id': 878511744934703104},
#  {'created_at': u'Sat Jun 24 06:47:10 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95297),
#   'retweet_count': 360,
#   'text': u'Support those who support u \U0001f525\U0001f525\U0001f525. @djkhaled https://t.co/bFuKv9FbTc https://t.co/0PCLYadYj0',
#   'tweet_id': 878504754778963968},
#  {'created_at': u'Sat Jun 24 04:12:37 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95301),
#   'retweet_count': 189,
#   'text': u'Tag a friend who did this ?? https://t.co/k1iwjLQDRk https://t.co/kVxgvs3YzK',
#   'tweet_id': 878465864370204672},
#  {'created_at': u'Sat Jun 24 00:14:33 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95305),
#   'retweet_count': 307,
#   'text': u'Speed kills \U0001f525\U0001f525\U0001f525\U0001f525 https://t.co/TA59kDUcNx https://t.co/UlGdseHA5Z',
#   'tweet_id': 878405951908433920},
#  {'created_at': u'Fri Jun 23 21:09:42 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95309),
#   'retweet_count': 354,
#   'text': u'\u270a\U0001f3fe\U0001f4a8\U0001f343 https://t.co/FUdMZ0D0jO',
#   'tweet_id': 878359431645347840},
#  {'created_at': u'Fri Jun 23 20:25:22 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95313),
#   'retweet_count': 115,
#   'text': u'step into the hot box office wit big snoop .\U0001f37f\U0001f3a5 https://t.co/P6Kr9cFquz',
#   'tweet_id': 878348274775670785},
#  {'created_at': u'Fri Jun 23 20:22:21 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95317),
#   'retweet_count': 23,
#   'text': u'https://t.co/sEQpVSE0XU https://t.co/9BwjZupTAu',
#   'tweet_id': 878347517812809730},
#  {'created_at': u'Fri Jun 23 17:49:10 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95320),
#   'retweet_count': 157,
#   'text': u'https://t.co/3e2siiTzN4 https://t.co/O4NBP72xMv',
#   'tweet_id': 878308964852572160},
#  {'created_at': u'Fri Jun 23 07:12:59 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95324),
#   'retweet_count': 151,
#   'text': u'Family 1st https://t.co/oR8eSA0y3e https://t.co/D975UtA9wJ',
#   'tweet_id': 878148866750730240},
#  {'created_at': u'Fri Jun 23 07:12:20 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95328),
#   'retweet_count': 111,
#   'text': u'18 now \U0001f339\U0001f496\U0001f370 https://t.co/PKwONrjBZv https://t.co/ZCUjQVx3tu',
#   'tweet_id': 878148702883467264},
#  {'created_at': u'Fri Jun 23 07:04:37 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95332),
#   'retweet_count': 63,
#   'text': u'https://t.co/rqnFSaj8YJ https://t.co/DcFmurwKbH',
#   'tweet_id': 878146762132692992},
#  {'created_at': u'Fri Jun 23 02:01:00 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95336),
#   'retweet_count': 59,
#   'text': u'My og. @therealdennisg \U0001f340\U0001f44c\U0001f3fe https://t.co/ykHvWdf4N8 https://t.co/puVUAOmvbO',
#   'tweet_id': 878070354303795201},
#  {'created_at': u'Fri Jun 23 01:51:11 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95340),
#   'retweet_count': 67,
#   'text': u'https://t.co/9ZdCLUtCgv https://t.co/0otVSCFxAX',
#   'tweet_id': 878067883712139265},
#  {'created_at': u'Fri Jun 23 00:31:20 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95344),
#   'retweet_count': 56,
#   'text': u'sky high . \U0001f343\u2601\ufe0f @leafsbysnoop https://t.co/NBhV9Mizo3 https://t.co/OtiyrfhO6R',
#   'tweet_id': 878047786482237440},
#  {'created_at': u'Thu Jun 22 19:12:13 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95348),
#   'retweet_count': 43,
#   'text': u'https://t.co/8foYI2Mkw2 https://t.co/Nj9Qv0IxMJ',
#   'tweet_id': 877967478940413952},
#  {'created_at': u'Thu Jun 22 17:55:45 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95352),
#   'retweet_count': 30,
#   'text': u'https://t.co/6kikAXAJ2G https://t.co/1mgiCTMxcf',
#   'tweet_id': 877948234815033344},
#  {'created_at': u'Thu Jun 22 17:54:17 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95356),
#   'retweet_count': 73,
#   'text': u'https://t.co/6wSTODThHN https://t.co/Bf9Sbs9Isa',
#   'tweet_id': 877947867289141248},
#  {'created_at': u'Thu Jun 22 17:49:35 +0000 2017',
#   'handle': u'Snoop Dogg',
#   'mined_at': datetime.datetime(2017, 10, 14, 14, 12, 19, 95360),
#   'retweet_count': 249,
#   'text': u'Cripn cuzns\U0001f44a\U0001f3fe\U0001f4b8\U0001f4b8 https://t.co/huuM43WeL8 https://t.co/6TGHIIWTru',
#   'tweet_id': 877946683631349760}]

# %%
pd.DataFrame(snoopdogg)
# Out:
#                          created_at      handle                   mined_at  \
# 0    Sat Oct 14 18:10:48 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330596
# 1    Sat Oct 14 16:44:52 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330607
# 2    Sat Oct 14 16:44:40 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330610
# 3    Sat Oct 14 03:58:46 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330612
# 4    Sat Oct 14 03:57:11 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330615
# 5    Sat Oct 14 03:56:48 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330618
# 6    Sat Oct 14 03:50:46 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330621
# 7    Fri Oct 13 23:36:04 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330623
# 8    Fri Oct 13 23:31:54 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330626
# 9    Fri Oct 13 23:10:21 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330629
# 10   Fri Oct 13 18:41:21 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330631
# 11   Fri Oct 13 17:43:00 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330634
# 12   Fri Oct 13 05:35:02 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330636
# 13   Fri Oct 13 00:42:17 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330639
# 14   Thu Oct 12 23:56:03 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330641
# 15   Thu Oct 12 09:08:56 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330643
# 16   Thu Oct 12 08:24:56 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330646
# 17   Thu Oct 12 08:24:47 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330649
# 18   Thu Oct 12 08:24:22 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330651
# 19   Thu Oct 12 08:23:11 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330654
# 20   Thu Oct 12 08:17:55 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330657
# 21   Thu Oct 12 00:43:58 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330659
# 22   Thu Oct 12 00:16:24 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330661
# 23   Wed Oct 11 19:05:18 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330664
# 24   Wed Oct 11 08:28:01 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330666
# 25   Wed Oct 11 05:03:12 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330668
# 26   Wed Oct 11 01:54:12 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330671
# 27   Wed Oct 11 00:40:36 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330673
# 28   Wed Oct 11 00:07:14 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330676
# 29   Tue Oct 10 23:30:41 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330678
# ..                              ...         ...                        ...
# 970  Sun Jun 25 19:57:48 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095247
# 971  Sun Jun 25 15:49:57 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095251
# 972  Sun Jun 25 12:59:20 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095255
# 973  Sun Jun 25 12:58:04 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095259
# 974  Sun Jun 25 03:22:25 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095263
# 975  Sat Jun 24 23:21:22 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095267
# 976  Sat Jun 24 23:21:20 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095271
# 977  Sat Jun 24 23:17:19 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095274
# 978  Sat Jun 24 20:02:29 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095278
# 979  Sat Jun 24 16:03:12 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095282
# 980  Sat Jun 24 15:07:57 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095285
# 981  Sat Jun 24 15:06:12 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095289
# 982  Sat Jun 24 07:14:56 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095293
# 983  Sat Jun 24 06:47:10 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095297
# 984  Sat Jun 24 04:12:37 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095301
# 985  Sat Jun 24 00:14:33 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095305
# 986  Fri Jun 23 21:09:42 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095309
# 987  Fri Jun 23 20:25:22 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095313
# 988  Fri Jun 23 20:22:21 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095317
# 989  Fri Jun 23 17:49:10 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095320
# 990  Fri Jun 23 07:12:59 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095324
# 991  Fri Jun 23 07:12:20 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095328
# 992  Fri Jun 23 07:04:37 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095332
# 993  Fri Jun 23 02:01:00 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095336
# 994  Fri Jun 23 01:51:11 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095340
# 995  Fri Jun 23 00:31:20 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095344
# 996  Thu Jun 22 19:12:13 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095348
# 997  Thu Jun 22 17:55:45 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095352
# 998  Thu Jun 22 17:54:17 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095356
# 999  Thu Jun 22 17:49:35 +0000 2017  Snoop Dogg 2017-10-14 14:12:19.095360
#
#      retweet_count                                               text  \
# 0               34  Oct 27 new snoop Dogg. 🔥🔥🔥🔌🇺🇸 https://t....
# 1              102  🤷🏾‍♂️🤷🏾‍♂️ https://t.co/zIp4SjWan7 https:/...
# 2              472    https://t.co/YV4XhnNCwI https://t.co/kRXxomBSXI
# 3               16  RT @TheOffical357: @SnoopDogg finna take over ...
# 4                3  RT @BoltVanderNerd: @JokersWildTBS @SnoopDogg ...
# 5                5  RT @BartMan247: @WinkMartindale what do you th...
# 6              370                     @awonderland @Pouyalilpou same
# 7               29  It's about that time 🙌🏿 who watchin ? https:...
# 8               44  who watchin ? #jokerswild https://t.co/S9VzYLHfjh
# 9              217  RT @JokersWildTBS: Can a rap kingpin turn into...
# 10             135  tickets available 2day . @rmmpercy does it aga...
# 11            1102  Sound like slavery to me 🤷🏾‍♂️ https://t.co/...
# 12             273    https://t.co/gM1DPuA0Zh https://t.co/zH6ZAfbtEm
# 13              95  about last night 👑 #JokersWild party. #Ginand...
# 14              44  🤣🤣 what y’all rockin wit ? https://t.co/OM3j...
# 15             101  My baby 💖🌹😘. @princessbroadus https://t.co/...
# 16             106    https://t.co/9PoSec3iWp https://t.co/GGGMX7mGP9
# 17              87    https://t.co/tlADFXUGH1 https://t.co/ou4RrHXbZP
# 18              37  @iamcardib 🤣🤣🤷🏾‍♂️🔌 https://t.co/6QDrRFep...
# 19              46  Damn.  Wce🌹💖😘😘😘. @bosslady_ent https://t....
# 20             136    https://t.co/17qxeDNFUo https://t.co/N6PsBAXdwo
# 21            1614    https://t.co/oQgOrLIFza https://t.co/NwU682j4Xg
# 22             261      what yall thinkin? 🤔 https://t.co/2Lq7jap3Fo
# 23             842  🤷🏾‍♂️🇺🇸 https://t.co/kCrHFeeriz https://t....
# 24            2485  🤷🏾‍♂️🇺🇸🤣🤣🤣👊🏾🔌 https://t.co/ESYE6xsrF...
# 25             288  👊🏾 https://t.co/7F0iXQOMCm https://t.co/5SWP...
# 26              42    https://t.co/06LbBxC6qF https://t.co/gtN04lRFgF
# 27             104  🤷🏾‍♂️ https://t.co/Ia6n7veAPe https://t.co/9...
# 28              57  what's yo strain name? #JokersWild https://t.c...
# 29              27   its about that time 🤘🏿 https://t.co/Kzc36NXvkQ
# ..             ...                                                ...
# 970            688           y'all know dis ? https://t.co/KvkAMBx5UE
# 971            153    https://t.co/oCwTmI5trK https://t.co/tkgyLIkO7p
# 972             30    https://t.co/un41K8aDb1 https://t.co/1fldaicbrq
# 973            218  Thug brothers 👊🏾🔥🔥 https://t.co/tWsY8UEXue...
# 974             40  champions hoops all summer long . @ChampsHoops...
# 975            251    https://t.co/3AQLitSc5D https://t.co/4N7FNtwzxC
# 976            150    https://t.co/wmhK91jvEt https://t.co/xs6cY9Ai2W
# 977             98  👊🏾👊🏾👊🏾👏🏾👏🏾🥂🥂🍀🍀 https://t.co/40q2...
# 978          14253  mexico know wat up .✊🏾🇲🇽 https://t.co/4SWUQ...
# 979           1384  They will do a little time https://t.co/9FeMFe...
# 980            108  Love 👊🏾 https://t.co/MOaPpt0RRA https://t.co...
# 981            202  Cuz https://t.co/lgyt5gD6vy https://t.co/7H3Q5...
# 982            573  @joeybadass https://t.co/UicWnhBtst https://t....
# 983            360  Support those who support u 🔥🔥🔥. @djkhaled ...
# 984            189  Tag a friend who did this ?? https://t.co/k1iw...
# 985            307  Speed kills 🔥🔥🔥🔥 https://t.co/TA59kDUcNx h...
# 986            354                    ✊🏾💨🍃 https://t.co/FUdMZ0D0jO
# 987            115  step into the hot box office wit big snoop .🍿...
# 988             23    https://t.co/sEQpVSE0XU https://t.co/9BwjZupTAu
# 989            157    https://t.co/3e2siiTzN4 https://t.co/O4NBP72xMv
# 990            151  Family 1st https://t.co/oR8eSA0y3e https://t.c...
# 991            111  18 now 🌹💖🍰 https://t.co/PKwONrjBZv https://...
# 992             63    https://t.co/rqnFSaj8YJ https://t.co/DcFmurwKbH
# 993             59  My og. @therealdennisg 🍀👌🏾 https://t.co/ykH...
# 994             67    https://t.co/9ZdCLUtCgv https://t.co/0otVSCFxAX
# 995             56  sky high . 🍃☁️ @leafsbysnoop https://t.co/NBh...
# 996             43    https://t.co/8foYI2Mkw2 https://t.co/Nj9Qv0IxMJ
# 997             30    https://t.co/6kikAXAJ2G https://t.co/1mgiCTMxcf
# 998             73    https://t.co/6wSTODThHN https://t.co/Bf9Sbs9Isa
# 999            249  Cripn cuzns👊🏾💸💸 https://t.co/huuM43WeL8 ht...
#
#                tweet_id
# 0    919264239222771712
# 1    919242611763838978
# 2    919242564670296064
# 3    919049816579043334
# 4    919049418996715520
# 5    919049323656110080
# 6    919047804810440705
# 7    918983709067329536
# 8    918982658591416320
# 9    918977237105360896
# 10   918909541143650304
# 11   918894856747053057
# 12   918711655466393600
# 13   918637984223604736
# 14   918626347676659712
# 15   918403097441067008
# 16   918392024973414400
# 17   918391989732855808
# 18   918391882673262592
# 19   918391587180285952
# 20   918390261390168064
# 21   918276021668982784
# 22   918269084235476992
# 23   918190790354010112
# 24   918030415155351552
# 25   917978869357010946
# 26   917931307677749248
# 27   917912782657544195
# 28   917904387866898434
# 29   917895189615714306
# ..                  ...
# 970  879066115401371648
# 971  879003738916220929
# 972  878960803063484416
# 973  878960485445644288
# 974  878815618203504641
# 975  878754956337197057
# 976  878754945725542400
# 977  878753934545997824
# 978  878704904138706944
# 979  878644688982560768
# 980  878630783178727426
# 981  878630343770865665
# 982  878511744934703104
# 983  878504754778963968
# 984  878465864370204672
# 985  878405951908433920
# 986  878359431645347840
# 987  878348274775670785
# 988  878347517812809730
# 989  878308964852572160
# 990  878148866750730240
# 991  878148702883467264
# 992  878146762132692992
# 993  878070354303795201
# 994  878067883712139265
# 995  878047786482237440
# 996  877967478940413952
# 997  877948234815033344
# 998  877947867289141248
# 999  877946683631349760
#
# [1000 rows x 6 columns]

# %%
snoopdogg_df = pd.DataFrame(snoopdogg)
aerosmith_df = pd.DataFrame(aerosmith)
flagaline_df = pd.DataFrame(flagaline)
lovato_df = pd.DataFrame(lovato)

# %%
tweets = pd.concat([snoopdogg_df, aerosmith_df, flagaline_df, lovato_df])

# %%
tweets.head(20)
# Out:
#                         created_at      handle                   mined_at  \
# 0   Sat Oct 14 18:10:48 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330596
# 1   Sat Oct 14 16:44:52 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330607
# 2   Sat Oct 14 16:44:40 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330610
# 3   Sat Oct 14 03:58:46 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330612
# 4   Sat Oct 14 03:57:11 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330615
# 5   Sat Oct 14 03:56:48 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330618
# 6   Sat Oct 14 03:50:46 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330621
# 7   Fri Oct 13 23:36:04 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330623
# 8   Fri Oct 13 23:31:54 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330626
# 9   Fri Oct 13 23:10:21 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330629
# 10  Fri Oct 13 18:41:21 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330631
# 11  Fri Oct 13 17:43:00 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330634
# 12  Fri Oct 13 05:35:02 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330636
# 13  Fri Oct 13 00:42:17 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330639
# 14  Thu Oct 12 23:56:03 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330641
# 15  Thu Oct 12 09:08:56 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330643
# 16  Thu Oct 12 08:24:56 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330646
# 17  Thu Oct 12 08:24:47 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330649
# 18  Thu Oct 12 08:24:22 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330651
# 19  Thu Oct 12 08:23:11 +0000 2017  Snoop Dogg 2017-10-14 14:12:17.330654
#
#     retweet_count                                               text  \
# 0              34  Oct 27 new snoop Dogg. 🔥🔥🔥🔌🇺🇸 https://t....
# 1             102  🤷🏾‍♂️🤷🏾‍♂️ https://t.co/zIp4SjWan7 https:/...
# 2             472    https://t.co/YV4XhnNCwI https://t.co/kRXxomBSXI
# 3              16  RT @TheOffical357: @SnoopDogg finna take over ...
# 4               3  RT @BoltVanderNerd: @JokersWildTBS @SnoopDogg ...
# 5               5  RT @BartMan247: @WinkMartindale what do you th...
# 6             370                     @awonderland @Pouyalilpou same
# 7              29  It's about that time 🙌🏿 who watchin ? https:...
# 8              44  who watchin ? #jokerswild https://t.co/S9VzYLHfjh
# 9             217  RT @JokersWildTBS: Can a rap kingpin turn into...
# 10            135  tickets available 2day . @rmmpercy does it aga...
# 11           1102  Sound like slavery to me 🤷🏾‍♂️ https://t.co/...
# 12            273    https://t.co/gM1DPuA0Zh https://t.co/zH6ZAfbtEm
# 13             95  about last night 👑 #JokersWild party. #Ginand...
# 14             44  🤣🤣 what y’all rockin wit ? https://t.co/OM3j...
# 15            101  My baby 💖🌹😘. @princessbroadus https://t.co/...
# 16            106    https://t.co/9PoSec3iWp https://t.co/GGGMX7mGP9
# 17             87    https://t.co/tlADFXUGH1 https://t.co/ou4RrHXbZP
# 18             37  @iamcardib 🤣🤣🤷🏾‍♂️🔌 https://t.co/6QDrRFep...
# 19             46  Damn.  Wce🌹💖😘😘😘. @bosslady_ent https://t....
#
#               tweet_id
# 0   919264239222771712
# 1   919242611763838978
# 2   919242564670296064
# 3   919049816579043334
# 4   919049418996715520
# 5   919049323656110080
# 6   919047804810440705
# 7   918983709067329536
# 8   918982658591416320
# 9   918977237105360896
# 10  918909541143650304
# 11  918894856747053057
# 12  918711655466393600
# 13  918637984223604736
# 14  918626347676659712
# 15  918403097441067008
# 16  918392024973414400
# 17  918391989732855808
# 18  918391882673262592
# 19  918391587180285952

# %%
emoji_key = pd.read_csv('emoji_table.txt', encoding = 'utf-8', index_col = 0)

# %%
emoji_count = defaultdict(int)
for i in tweets['text']:
    for emoji in re.findall(u'\u2026', i):
        emoji_count[emoji] += 1

print (emoji_count)
# Out:
# defaultdict(<type 'int'>, {u'\u2026': 1004})

# %%
import socialmediaparse as smp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-0a06cbccf970> in <module>()
# ----> 1 import socialmediaparse as smp
#
# ImportError: No module named socialmediaparse

# %%
with open('emoji_out.csv', 'w') as f:
    emoji_count.to_csv(f, sep=',', index = False, encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2655a75c2533> in <module>()
#       1 with open('emoji_out.csv', 'w') as f:
# ----> 2     emoji_count.to_csv(f, sep=',', index = False, encoding = 'utf-8')
#
# NameError: name 'emoji_count' is not defined

# %%
tweets.to_csv('bindext.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-35-d66d15d6d3cf> in <module>()
# ----> 1 tweets.to_csv('bindext.csv')
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/pandas/io/formats/format.pyc in save(self)
#    1584                 self.writer = csv.writer(f, **writer_kwargs)
#    1585
# -> 1586             self._save()
#    1587
#    1588         finally:
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/pandas/io/formats/format.pyc in _save(self)
#    1685                 break
#    1686
# -> 1687             self._save_chunk(start_i, end_i)
#    1688
#    1689     def _save_chunk(self, start_i, end_i):
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/pandas/io/formats/format.pyc in _save_chunk(self, start_i, end_i)
#    1711                                         quoting=self.quoting)
#    1712
# -> 1713         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#    1714
#    1715
#
# pandas/_libs/lib.pyx in pandas._libs.lib.write_csv_rows (pandas/_libs/lib.c:19799)()
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2026' in position 138: ordinal not in range(128)

# %% [markdown]
# ### Convert the tweet ouputs to a pandas DataFrame
#
# > *Hint: this is as easy as passing it to the DataFrame constructor!*

# %%
# A:

# %% [markdown]
# ##  Create the training data
#
# ---
#
# Let's get our "mined" data from the Twitter API.
#
# 1. Mine Trump tweets
# - Create a tweet DataFrame
# - Mine Sanders tweets
# - Append the results to our DataFrame

# %%
# A:

# %% [markdown]
# ## Any interesting ngrams going on with Trump?
# ---
#
# Set up a vectorizer from sklearn and fit the text of Trump's tweets with an ngram range from 2 to 4. Figure out what the most common ngrams are.
#
# > **Note:** It's up to you whether you want to remove stopwords or not. How does keeping or removing stopwords affect the results?

# %%
# f = vect.build_analyzer()
# f(summaries)

# %%
# A:
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter

vect = CountVectorizer(ngram_range=(2,4))

summaries = ''.join (snoopdogg['text'])
ngram_sum = vect.build_analyzer()(summaries)

Counter(ngram_sum).most_common(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-26000dde1625> in <module>()
#       5 vect = CountVectorizer(ngram_range=(2,4))
#       6
# ----> 7 summaries = ''.join (snoopdogg['text'])
#       8 ngram_sum = vect.build_analyzer()(summaries)
#       9
#
# TypeError: list indices must be integers, not str

# %% [markdown]
# ### Look at the ngrams for Snoop Dogg

# %% [markdown]
# ## Processing the tweets and building a model
#
# ---
#
# To do classfication we will need to convert the tweets into a set of features.
#
# **You will need to:**
# - Vectorize input text data.
# - Intialize a model (try Logistic regression).
# - Train / Predict / cross-validate.
# - Evaluate the performance of the model.
#
# > **Bonus:** you may have noticed that there are website links in the tweets. What additional preprocessing steps can you do before building the model?

# %%
tweets.head(2)
# Out:
#                        created_at          handle                   mined_at  \
# 0  Wed Oct 22 14:02:38 +0000 2014  RealDonalTrump 2017-06-16 11:24:33.118335
# 1  Mon Sep 08 10:29:39 +0000 2014  RealDonalTrump 2017-06-16 11:24:33.118346
#
#    retweet_count                                               text  \
# 0             19  Reply to @conor_pope @broadsheet_ie  Just as w...
# 1              6  @leahysarah "It's hard to believe that Norma l...
#
#              tweet_id
# 0  524923787658412033
# 1  508925124092116992

# %%
# A:

tweets['target'] = tweets.handle.map(lambda x: 1 if x == 'RealDonalTrump' else 0)

# %%
tweets.head(3)

# now we have the target at the last columns
# Out:
#                        created_at          handle                   mined_at  \
# 0  Wed Oct 22 14:02:38 +0000 2014  RealDonalTrump 2017-06-16 11:24:33.118335
# 1  Mon Sep 08 10:29:39 +0000 2014  RealDonalTrump 2017-06-16 11:24:33.118346
# 2  Mon Sep 08 10:27:43 +0000 2014  RealDonalTrump 2017-06-16 11:24:33.118349
#
#    retweet_count                                               text  \
# 0             19  Reply to @conor_pope @broadsheet_ie  Just as w...
# 1              6  @leahysarah "It's hard to believe that Norma l...
# 2             13  RT @paula_span: Gay Men's Chorus singing "Ther...
#
#              tweet_id  target
# 0  524923787658412033       1
# 1  508925124092116992       1
# 2  508924636965666817       1

# %%
X = tweets.text
y = tweets.target

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size =0.8)

# %%
# cvt = CountVectorizer(ngram_range=(1, 3))
# Xcvt = cvt.fit_transform(X_train)
# test_cvt = cvt.transform(X_test)

# # We fit.transform the train, but ONLY transform test!!!!!

# %%
# lr = LogisticRegression()
# lr.fit(Xcvt, y_train)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(logit, test_cvt, y_test, cv = 5)

# %%
# grab the confusion matrix 

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
def eval_model(model, x_test, y_true):
    y_pred = model.predict(x_test)
    conmat_1 = confusion_matrix(y_true, y_pred, labels=model.classes_)
    conmat_1 = pd.DataFrame(conmat_1, columns=model.classes_, index=model.classes_)
    print(accuracy_score(y_true,y_pred))
    print(conmat_1)
    print(classification_report(y_true,y_pred ))

# %% [markdown]
# ## Check the predicted probability for a random Sanders and Trump tweet
# ---
#
# Below are provided a couple of tweets from both Sanders and Trump. I'm sure you can figure out on your own which one is which.
#
# Estimate the predicted probability of being trump for the two tweets.

# %%
# Prep our source as TfIdf vectors
source_test = [
    "Demanding that the wealthy and the powerful start paying their fair share of taxes that's exactly what the American people want.",
    "Crooked Hillary is spending tremendous amounts of Wall Street money on false ads against me. She is a very dishonest person!"
]

############
# NOTE:  Do not re-initialize the tfidf vectorizor or the feature space willbe overwritten and
# hence your transform will not match the number of features you trained your model on.
#
# This is why you only need to "transform" since you already "fit" previously
#
####

# %% [markdown]
# ## Independent practice questions
#
# ---

# %% [markdown]
# ### 1. Pull tweets for some new users.
#
# Experiment with using more data.  The API will not like it if you blow through their limits - be careful.  Try to grab only what you need one time, then work on the copy of the objects that are returned.
#
# > Read the documentation about rate limits and see if you can get enough without hitting the rate limit.  Are there any options available in the API to avoid such a problem?
#
# **Pull tweets for more than two different users of your choice.**

# %%
# A:
# First, mine tweets from users. I choose Neil Tyson and Bill Nye because 
# I admire these two science guys a lot :-)

neiltyson = miner.mine_user_tweets(user = 'neiltyson')
billnye = miner.mine_user_tweets(user = 'BillNye')

# %%
neiltyson[:2]
# Out:
# [{'created_at': u'Mon Jul 31 16:08:45 +0000 2017',
#   'handle': u'Neil deGrasse Tyson',
#   'mined_at': datetime.datetime(2017, 7, 31, 23, 13, 15, 409870),
#   'retweet_count': 520,
#   'text': u"POSTED Full Episode Video of @StarTalkRadio's \u201cLet\u2019s Make America Smart Again w/ @FareedZakaria\u201d On https://t.co/4GIbbIYJdu",
#   'tweet_id': 892054433416318977},
#  {'created_at': u'Sat Jul 29 20:46:36 +0000 2017',
#   'handle': u'Neil deGrasse Tyson',
#   'mined_at': datetime.datetime(2017, 7, 31, 23, 13, 15, 409883),
#   'retweet_count': 1652,
#   'text': u'@JJWatt @Djread98 Whoever told him that Dinosaur fossils are fake, does not hold his intellectual enlightenment as a priority.',
#   'tweet_id': 891399582592126977}]

# %%
# Then I put the two scientists' tweets into dataframes
neiltyson_df = pd.DataFrame(neiltyson)
billnye_df = pd.DataFrame(billnye)

# %%
# Then I combine the two tweets dataframes together as one. 
science_tweets = pd.concat([neiltyson_df, billnye_df])

# %%
# check sample dataframe
science_tweets.tail()
# Out:
#                          created_at    handle                   mined_at  \
# 994  Tue Jun 17 14:31:36 +0000 2014  Bill Nye 2017-06-16 11:42:49.375003
# 995  Tue Jun 17 14:27:05 +0000 2014  Bill Nye 2017-06-16 11:42:49.375006
# 996  Tue Jun 17 14:22:51 +0000 2014  Bill Nye 2017-06-16 11:42:49.375009
# 997  Tue Jun 17 14:20:27 +0000 2014  Bill Nye 2017-06-16 11:42:49.375011
# 998  Tue Jun 17 14:15:07 +0000 2014  Bill Nye 2017-06-16 11:42:49.375014
#
#      retweet_count                                               text  \
# 994             10  @JordannnHarris - 3c's: Cold, Corrosive, &amp;...
# 995            709  If ocean changes dramatically, we will suffer....
# 996             75  Should we tax fish catches to discourage waste...
# 997            463  Climate change is Nat'l security issue- clean ...
# 998            128  What we (you) doing to bring climate change de...
#
#                tweet_id
# 994  478907817378598912
# 995  478906682261520385
# 996  478905617029931009
# 997  478905014111305729
# 998  478903670558302208

# %% [markdown]
# ### 2. Build a multi-class classification model to distinguish between the users.
#
# Try a new type of model than we used before.

# %%
# A:

# I am trying to predict with tweet content. 
# Giving a tweet that I can predict if the tweet belong to Neil or Bill.

# So I will create a target column and map Neil as 1 and Bill as 0

science_tweets['neil_or_bill'] = science_tweets.handle.map(lambda x: 1 if x == 'Neil deGrasse Tyson' else 0)

# %%
# check if the "neil_or_bill" column is created

science_tweets.head(2)

# Cool. Now Neil is mapped to 1 and Bill maped to 0
# Out:
#                        created_at               handle  \
# 0  Thu Jun 15 12:12:51 +0000 2017  Neil deGrasse Tyson
# 1  Thu Jun 15 02:15:49 +0000 2017  Neil deGrasse Tyson
#
#                     mined_at  retweet_count  \
# 0 2017-06-16 11:42:43.244740            485
# 1 2017-06-16 11:42:43.244754           2164
#
#                                                 text            tweet_id  \
# 0  Tired of soundbites? CSPAN Video of me address...  875325226690727936
# 1  Would be cool if all Departments of Motor Vehi...  875174978743926784
#
#    neil_or_bill
# 0             1
# 1             1

# %%
# Next..I need to prepare X and y. X will be the text data for training. y is the neil_or_bill column

X = science_tweets.text
y = science_tweets.neil_or_bill

# %%
# Check the dimension of X & y
print X.shape
print y.shape
# Out:
# (1999,)
# (1999,)

# %%
# Then I split the dataset into train/test dataset. I will use 30% of the data for testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# Time to vectorize the tweets! I will use ngram 2, 3 for a try

vectorizer = CountVectorizer(ngram_range=(2,3))
X_train_t = vectorizer.fit_transform(X_train)
X_test_t = vectorizer.transform(X_test)

type(X_train_t)
type(X_test_t)

# ok, the training tweets are being fit and transformed into the document-term sparse matrix
# The test tweets are being transform ONLY into document-term spare matrix
# Out:
# scipy.sparse.csr.csr_matrix

# %%
# I decide to use BeroulliNB for modeling
# import BernoulliNB from sklearn naive bayes. 
from sklearn.naive_bayes import BernoulliNB

# instantiate the model
bernnb = BernoulliNB()

# fit the vectorized training tweets
bernnb.fit(X_train_t, y_train)

# Let's do some prediction

y_pred = bernnb.predict(X_test_t)

y_pred[:10]
# Out:
# array([0, 1, 1, 1, 0, 0, 0, 1, 1, 1])

# %%
# Cross validate the accuracy score for using BernoulliNB

from sklearn.model_selection import cross_val_score

accuracy_score = cross_val_score(bernnb, X_test_t, y_test, cv = 5)
accuracy_score = accuracy_score.mean()
accuracy_score
# Out:
# 0.56833333333333336

# %%
# The accuracy score is only 0.568, not very impressive. I think they both tweet alike. 
# Changing ngram may yield better prediction.
# Let's check the base accuracy to commpare

base_acc = y_test.value_counts()/len(y_test)
base_acc
# Out:
# 0    0.508333
# 1    0.491667
# Name: neil_or_bill, dtype: float64

# %% [markdown]
# #### Well, the base accuracy is only 0.49. I think the score is actually not bad.

# %% [markdown]
# ### 3. Make a confusion matrix and classification report.

# %%
# A:

from sklearn.metrics import confusion_matrix

confusion = confusion_matrix(y_test, y_pred)

confusion_matrix = pd.DataFrame(confusion, index = ['Actual: 0', 'Actual: 1'],
                               columns = ['Predicted: 0', 'Predicted: 1'])
print confusion_matrix
# Out:
#            Predicted: 0  Predicted: 1
# Actual: 0           297             8
# Actual: 1           139           156

# %% [markdown]
# ##### So 297 tweets are from Bill and we predicted it. 156 from Neil and we also predicted it correctly.
# ##### 8 tweets that we predicted from Neil but are actually from Bill.
# ##### I didn't do a good job predicting Bill. Most of them should be from Neil, 139 of them.

# %% [markdown]
# ### 4. What is the most and least "distinctive" tweets for each user?
#
# To find this, identify the tweet that has the highest (correct) predicted probability of being that user's tweet for each user.

# %%
science_tweets.head(2)
# Out:
#                        created_at               handle  \
# 0  Thu Jun 15 12:12:51 +0000 2017  Neil deGrasse Tyson
# 1  Thu Jun 15 02:15:49 +0000 2017  Neil deGrasse Tyson
#
#                     mined_at  retweet_count  \
# 0 2017-06-16 11:42:43.244740            485
# 1 2017-06-16 11:42:43.244754           2164
#
#                                                 text            tweet_id  \
# 0  Tired of soundbites? CSPAN Video of me address...  875325226690727936
# 1  Would be cool if all Departments of Motor Vehi...  875174978743926784
#
#    neil_or_bill
# 0             1
# 1             1

# %%
cvec = CountVectorizer(ngram_range = (2,3))
X2 = cvec.fit_transform(X)

# %%
# A:
pp = bernnb.predict_proba(X2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-f62673169293> in <module>()
#       1 # A:
# ----> 2 pp = bernnb.predict_proba(X2)
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in predict_proba(self, X)
#     101             order, as they appear in the attribute `classes_`.
#     102         """
# --> 103         return np.exp(self.predict_log_proba(X))
#     104
#     105
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in predict_log_proba(self, X)
#      81             order, as they appear in the attribute `classes_`.
#      82         """
# ---> 83         jll = self._joint_log_likelihood(X)
#      84         # normalize by P(x) = P(f_1, ..., f_n)
#      85         log_prob_x = logsumexp(jll, axis=1)
#
# /Users/connie/anaconda/envs/Connie_python2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in _joint_log_likelihood(self, X)
#     816         if n_features_X != n_features:
#     817             raise ValueError("Expected input with %d features, got %d instead"
# --> 818                              % (n_features, n_features_X))
#     819
#     820         neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
#
# ValueError: Expected input with 35404 features, got 49052 instead

# %%
from sklearn.feature_extraction.text import HashingVectorizer, TfidfVectorizer
